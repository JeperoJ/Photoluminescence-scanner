# %%
import numpy as np
import os
import sys
import tkinter as tk
import tifffile
import src.utils.ingaas_processing as ingaas_processing
from src import stitching
from src.stitching import helpers
import cv2
from matplotlib import pyplot as plt
from tkinter import filedialog
import scipy
#import toml_rs as tml
import io

# %%
import manualStitch

mod_freq = 50
fps = 150
print(f"mod_freq: {mod_freq}, fps: {fps}")
im_path = filedialog.askopenfilename(title='Select image to process')
out_path = filedialog.askopenfilename(title='Select output image path')
images = np.array(tifffile.imread(im_path))

manualStitch.separateModulated(im_path)
